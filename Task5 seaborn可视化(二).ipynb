# %% [markdown]
# # Task5 seaborn可视化（二）

# %% [markdown]
# - 本章知识点：
#     - 双变量关系图：jointplot()
#     - 变量关系组图：pairplot()
#     - 直方图，质量估计图：distplot()
#     - 核函数密度估计图：kdeplot()
#     - 回归模型图：lmplot()
#     - 线性回归图：regplot()
#     - 热力图：heatmap()
# - 小作业：
#     - 用countplot()函数，绘制条形图，看看每年到底有多少地震发生；
#     - 作热力图heatmap去看看近十年来的地震记录；

# %% [markdown]
# ## 1. 导入相关库

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## 2. 读取相关文件

# %%
#如果报错，可以去https://github.com/mwaskom/seaborn-data，将数据集下载到本地，设置cache参数为True，data_home放本地路径；
#tip = sns.load_dataset('tips')
#tip 

filepath = '/home/mw/input/data1329'
tips = sns.load_dataset("tips", cache=True, data_home=filepath)
iris = sns.load_dataset("iris", cache=True, data_home=filepath)
ans = sns.load_dataset("anscombe", cache=True, data_home=filepath)
flights = sns.load_dataset("flights", cache=True, data_home=filepath)

# %% [markdown]
# ## 3.双变量关系图：jointplot()

# %% [markdown]
# - 在默认情况下双变量关系图是散点图与直方图组合的联合直方图，可以通过设置kind来改变联合直方图。

# %% [markdown]
# ### 3.1 绘制散点图，边缘为直方图：联合直方图

# %%
sns.jointplot(x="total_bill", y="tip", data=tips)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/4E8E65DA67084C3789F05A26CB08E645/qqt6yc2995.png">

# %% [markdown]
# ### 3.2 在联合添加回归和核密度拟合

# %%
sns.jointplot("total_bill", "tip", data=tips, kind="reg")
# Out:
# <img src="https://cdn.kesci.com/upload/rt/9D7189D699D043518DEF630301C5A656/qqt6ydxxzk.png">

# %% [markdown]
# ### 3.3 使用六边形点代替联合直方图中的圆形散点

# %%
sns.jointplot("total_bill", "tip", data=tips, kind="hex")
# Out:
# <img src="https://cdn.kesci.com/upload/rt/4B3D50F31D674D65A2DBEE68E5BEDFED/qqt6ydvb8c.png">

# %% [markdown]
# ### 3.4 将散点图和直方图均替换为核密度估计

# %%
sns.jointplot("sepal_width", "petal_length", data=iris,
              kind="kde", space=0, color="g")
# Out:
# <img src="https://cdn.kesci.com/upload/rt/4F4DE8FF02B0475C8C7BB2CDCEE5A41A/qqt6yewosc.png">

# %% [markdown]
# ## 4. 变量关系组图：pairplot()

# %% [markdown]
# ### 4.1 为联合关系绘制散点图，为单变量绘制直方图

# %%
sns.pairplot(iris)

#由于值为数字的字段变量有4个，故绘制的关系图为4x4
# Out:
# <img src="https://cdn.kesci.com/upload/rt/D6B25D9648BC495C8C999EFC8C157F48/qqt6yi2x1q.png">

# %% [markdown]
# ### 4.2 为联合关系绘制散点图，为单变量绘制核密度估计图

# %%
sns.pairplot(iris, hue="species")
# Out:
# <img src="https://cdn.kesci.com/upload/rt/CA38977E699C4D84930BB6862EA1FA53/qqt6yn43l4.png">

# %% [markdown]
# ### 4.3 指定markers来设置散点图中的点形

# %%
sns.pairplot(iris, hue="species", markers=["o", "s", "D"])
# Out:
# <img src="https://cdn.kesci.com/upload/rt/412A4FACA2134FECAD5CB478B91BE20A/qqt6yr8803.png">

# %% [markdown]
# ### 4.4 指定vars=["sepal_width", "sepal_length"]显式展示指定变量名对应的数据

# %%
sns.pairplot(iris,vars=["sepal_width", "sepal_length"])
# Out:
# <img src="https://cdn.kesci.com/upload/rt/AAAF8EF66AAE46D48566E421A4E02A31/qqt6ysxbz9.png">

# %% [markdown]
# ### 4.5 通过设置diag_kind指定绘制图类型(kde核密度估计图)

# %%
sns.pairplot(iris, diag_kind="kde")
# Out:
# <img src="https://cdn.kesci.com/upload/rt/8009D042D41A4A3A86774C15F33A2D62/qqt6yvfjpl.png">

# %% [markdown]
# ### 4.6 设置kind=reg为散点图添加线性回归模型

# %%
sns.pairplot(iris, kind="reg")
# Out:
# <img src="https://cdn.kesci.com/upload/rt/46F522C222F144E5B96C3F1BED8C8653/qqt6z0a51y.png">

# %% [markdown]
# ## 5. 直方图：distplot()

# %% [markdown]
# - seaborn.distplot() 直方图，质量估计图，核密度估计图
# - 该API可以绘制分别直方图和核密度估计图，也可以绘制直方图和核密度估计图的合成图 通过设置默认情况下，是绘制合成图，设置情况图下：
#     - hist=True:表示要绘制直方图(默认情况为True)，若为False，则不绘制
#     - kde=True:表示要绘制核密度估计图(默认情况为True),若为False,则绘制

# %% [markdown]
# ### 5.1 绘制直方图

# %%
sns.set() # 设置默认灰色网格主题
x = np.random.normal(size=100) # 生成高斯数据100个
sns.distplot(x)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/87F36D4CDAFB42428F865F0CBDE33E61/qqt6z15dq5.png">

# %% [markdown]
# ### 5.2 去掉直方图中的核密度曲线

# %%
# 如果不想要核密度估计添加参数kde=False
sns.distplot(x, kde=False)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/0E29B57724704666808CEB0B730FE395/qqt6z1ryvc.png">

# %% [markdown]
# ### 5.3 设置直方图组数为20

# %%
sns.distplot(x, bins=20, kde=False) # bins把数据切分成20份
# Out:
# <img src="https://cdn.kesci.com/upload/rt/996CFD1FE423412CAEB1838854807427/qqt6z15v4o.png">

# %% [markdown]
# ## 6. 核函数密度估计图：kdeplot()

# %% [markdown]
# - 该图主要用来拟合并绘制单变量或双变量核密度估计值。

# %% [markdown]
# ### 6.1 绘制基本的单变量密度曲线图

# %%
#构建数据
mean, cov = [0, 2], [(1, .5), (.5, 1)]
x, y = np.random.multivariate_normal(mean, cov, size=50).T

sns.kdeplot(x)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/B8159C1D20EB43998060DB36CB3C8F25/qqt6z1uh34.png">

# %% [markdown]
# ### 6.2 绘制密度曲线，并在曲线下着色通过设置color来设置不同的显示颜色

# %%
sns.kdeplot(x, shade=True, color="g")
# Out:
# <img src="https://cdn.kesci.com/upload/rt/47A3F74998CC41E8B611C6ED33C22F92/qqt6z2wrf1.png">

# %% [markdown]
# ### 6.3 绘制双变量密度曲线

# %%
sns.kdeplot(x, y)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/AF1891E7BB834CE884519C1FBC1591C0/qqt6z2poxv.png">

# %% [markdown]
# ### 6.4 使用轮廓填充，并给轮廓添加颜色条

# %%
sns.kdeplot(x, y, shade=True, cbar=True, color='r')
# Out:
# <img src="https://cdn.kesci.com/upload/rt/2DE6581CF20A43CB9E20609EF063B050/qqt6z3gv4b.png">

# %% [markdown]
# ## 6.5 绘制多个阴影双变量密度图(这里绘制两个)

# %%
setosa = iris.loc[iris.species == "setosa"]
virginica = iris.loc[iris.species == "virginica"]

sns.kdeplot(setosa.sepal_width, setosa.sepal_length, cmap="Reds", shade=True, shade_lowest=False)
sns.kdeplot(virginica.sepal_width, virginica.sepal_length, cmap="Blues", shade=True, shade_lowest=False)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/82CDC0CAAB5847E19261D775FE872CE5/qqt6z4dpo0.png">

# %% [markdown]
# ## 7. 回归模型图：implot()

# %% [markdown]
# - 回归模型图可以对数据进行回归显示。

# %% [markdown]
# ### 7.1 绘制两变量之间的简单线性关系

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/D2362E7E424F46B4837E1998645337B2/qqt6z5hfyq.png">

# %% [markdown]
# ### 7.2 通过设置hue对数据进行第二次分组(通过对颜色进行区分)

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/1A9AFE2E919D46C7827B2B4A3BD15147/qqt6z51tdt.png">

# %% [markdown]
# ### 7.3 通过设置markers对数据点进行不同的标记

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker",
            data=tips,markers=["o", "x"])
# Out:
# <img src="https://cdn.kesci.com/upload/rt/5B06E8F170CD4D99949144578084874F/qqt6z6qrh7.png">

# %% [markdown]
# ### 7.4 通过设置col指定变量名，以该变量名的内容进行分类

# %% [markdown]
# - 每一个类别下的数据绘制一个图(即该变量名下有多少类值就绘制多少个图，并且排列在一行上)

# %%
sns.lmplot(x="total_bill", y="tip", 
           col="smoker", data=tips)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/16E068684AD54878872CD7F758EEF3FA/qqt6z7dm5f.png">

# %% [markdown]
# ## 8. 线性回归图：regplot()

# %% [markdown]
# - 利用线性回归模型对数据进行拟合。

# %% [markdown]
# ### 8.1 绘制双变量的线性关系

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/316F032615F64C1D8E155DB03B7E44E2/qqt6z7ytfs.png">

# %% [markdown]
# ### 8.2 设置ci=68:使用68%的置信区间，该区间对应于估计的标准误差

# %%
sns.regplot(x=x, y=y, ci=68)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/DF5647AC8B9F419C9BBCA428EC2DDDFF/qqt6z75ync.png">

# %% [markdown]
# ### 8.3 拟合高阶多项式回归并阶段模型预测

# %%
sns.regplot(x="x", y="y",
            data=ans.loc[ans.dataset == "II"],
            scatter_kws={"s": 80},
            order=2, ci=None, truncate=True)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/FA29163626EC4246858C030D4BB0E189/qqt6z82abr.png">

# %% [markdown]
# ### 8.4 拟合logistic 回归(logistic=True)，对y轴数据进行抖动(y_jitter=.03)，并进行适当的迭代(n_boot=500)

# %%
tips["big_tip"] = (tips.tip / tips.total_bill) > .175

sns.regplot(x="total_bill", y="big_tip", 
            data=tips,logistic=True, 
            n_boot=500, y_jitter=.03)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/89D0C14FF4D04DA4809BA27BC8EE1202/qqt6z99afq.png">

# %% [markdown]
# ## 9. 热力图：heatmap()

# %% [markdown]
# - 将矩形数据绘制成颜色编码矩阵

# %% [markdown]
# ### 9.1 对10x12的数据绘制热力图

# %%
uniform_data = np.random.rand(10, 12)
sns.heatmap(uniform_data)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/6EA90424CCBF481686E9BC6B6C679DE8/qqt6z9twx0.png">

# %% [markdown]
# ### 9.2 更改 colormap的限制：vmin=0, vmax=1

# %%
sns.heatmap(uniform_data, vmin=0, vmax=1)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/25933C350A024C768358826670FB3EAD/qqt6zagkhf.png">

# %% [markdown]
# ### 9.3 直接对flights数据集中数据进行热力图显示

# %%
flights = flights.pivot("month", "year", "passengers")
sns.heatmap(flights)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/BF33F6CB8D0749EEA1299478DE0DC77F/qqt6za1fp.png">

# %% [markdown]
# ### 9.4 对每个单元格进行数值显示

# %%
sns.heatmap(flights, annot=True, fmt="d")
# Out:
# <img src="https://cdn.kesci.com/upload/rt/274C3B6B7E74403DB5D6140EC9C94F88/qqt6zbf6om.png">

# %% [markdown]
# ### 9.5 绘制每个单元格的边框

# %%
sns.heatmap(flights, linewidths=.5)
# Out:
# <img src="https://cdn.kesci.com/upload/rt/F18E1D4A5A8D43F59D9C145573051416/qqt6zcikmy.png">

# %% [markdown]
# ### 9.6 使用不同的colormap进行颜色显示

# %%
sns.heatmap(flights, cmap="YlGnBu")
# Out:
# <img src="https://cdn.kesci.com/upload/rt/0509F45F5F804489848CAE1C78CC5A78/qqt6zdl0j0.png">

# %% [markdown]
# ## 小作业：

# %% [markdown]
# ### 第一题：用countplot作图，绘制条形图
# - 步骤:
#     - 读取1965-2016年全球重大地震数据；
#     - 设置Date类型为datetime类型，并添加年份和月份两列；
#     - 筛选出type为地震的数据；
#     - 用countplot()函数，绘制条形图，横轴为年份，纵轴为数量，看看每年到底有多少地震发生；

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#数据处理
data = pd.read_csv('/home/mw/input/data1625/earthquake.csv')
data['Date'] = pd.to_datetime(data['Date'], format = "%m/%d/%Y", errors = 'coerce')
data['Year'] = data['Date'].dt.year
data['Month'] = data['Date'].dt.month
data = data[data['Type'] == 'Earthquake']

#可视化处理
plt.figure(1,figsize=(12,6)) 
Year = [i for i in range(1965,2017,5)]
idx = [i for i in range(0,52,5)]
sns.countplot(data['Year'])
plt.setp(plt.xticks(idx,Year)[1],rotation=45)
plt.title('Earthquake counts in history from year 1965 to year 2016')
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/D77CF751E8CD4BEDB59172FEE0387E05/qqt6zzy7uf.png">

# %% [markdown]
# ### 第二题：作热力图heatmap去看看近十年来的地震记录
# - 步骤:
#     - 按年份和月份列进行分组，取出年份、月份及ID列；
#     - 删选出近十年的数据；
#     - 将年份、月份及ID列做成数据透视表；
#     - 将近十年来的地震记录数按照年份和月份做热力图
#     - 设置一个标题：'近10年地震发生次数'

# %%
test = data.groupby([data['Year'],data['Month']],as_index=False).count()
new = test[['Year','Month','ID']]
temp = new.iloc[-120:,:]
temp = temp.pivot('Year','Month','ID')
sns.heatmap(temp)
plt.title('Earthquake happened in recent 10 years')
plt.show()
# Out:
# <img src="https://cdn.kesci.com/upload/rt/0AA9DE4F5A0843BE86411DCE91545D48/qqt70437nn.png">
